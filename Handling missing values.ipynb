# %% [markdown]
# # Handling missing values

# %% [markdown]
# Data cleaning is one those things that everyone does but no one really talks about. Sure, it’s not the "sexiest" part of machine learning. And no, there aren’t hidden tricks and secrets to uncover.

# %% [markdown]
# However, proper data cleaning can make or break your project. Professional data scientists usually spend a very large portion of their time on this step.
#
# Why? Because of a simple truth in machine learning:
#
# <b color="Red">Better data beats fancier algorithms.</b>

# %% [markdown]
# ## Approach 1 :

# %% [markdown]
# Here are several useful functions to detecting, replace, and remove null values in Pandas DataFrame :
#
# a. isnull()
#
# b. notnull()
#
# c. dropna()
#
# d. fillna()
#
# e. replace()

# %% [markdown]
# <h2>Reading the data</h2>

# %%
import pandas as pd
import numpy as np

titanic_train = pd.read_csv(
    "https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')

# %%
data=titanic_train[20:30]

# %%
df=data[['Name','Sex','Age','Ticket','Fare']]
df
# Out:
#                                                  Name     Sex   Age  Ticket  \
# 20                               Fynney, Mr. Joseph J    male  35.0  239865
# 21                              Beesley, Mr. Lawrence    male  34.0  248698
# 22                        McGowan, Miss. Anna "Annie"  female  15.0  330923
# 23                       Sloper, Mr. William Thompson    male  28.0  113788
# 24                      Palsson, Miss. Torborg Danira  female   8.0  349909
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0  347077
# 26                            Emir, Mr. Farred Chehab    male   NaN    2631
# 27                     Fortune, Mr. Charles Alexander    male  19.0   19950
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN  330959
# 29                                Todoroff, Mr. Lalio    male   NaN  349216
#
#         Fare
# 20   26.0000
# 21   13.0000
# 22    8.0292
# 23   35.5000
# 24   21.0750
# 25   31.3875
# 26    7.2250
# 27  263.0000
# 28    7.8792
# 29    7.8958

# %%
df.isnull()
# Out:
#      Name    Sex    Age  Ticket   Fare
# 20  False  False  False   False  False
# 21  False  False  False   False  False
# 22  False  False  False   False  False
# 23  False  False  False   False  False
# 24  False  False  False   False  False
# 25  False  False  False   False  False
# 26  False  False   True   False  False
# 27  False  False  False   False  False
# 28  False  False   True   False  False
# 29  False  False   True   False  False

# %% [markdown]
# <h2> a. isNull() </h2>

# %%
#this will return the rows consists of NaN values
firstdf=df[df.isnull().any(1)] 
firstdf
# Out:
#                              Name     Sex  Age  Ticket    Fare
# 26        Emir, Mr. Farred Chehab    male  NaN    2631  7.2250
# 28  O'Dwyer, Miss. Ellen "Nellie"  female  NaN  330959  7.8792
# 29            Todoroff, Mr. Lalio    male  NaN  349216  7.8958

# %%
#this will return the rows consists of NaN values basis of a particular column
seconddf=pd.isnull(df['Age']) 
df[seconddf]
# Out:
#                              Name     Sex  Age  Ticket    Fare
# 26        Emir, Mr. Farred Chehab    male  NaN    2631  7.2250
# 28  O'Dwyer, Miss. Ellen "Nellie"  female  NaN  330959  7.8792
# 29            Todoroff, Mr. Lalio    male  NaN  349216  7.8958

# %% [markdown]
# <h2> b. notNull() </h2>

# %%
seconddf=pd.notnull(df['Age'])
df[seconddf]
# Out:
#                                                  Name     Sex   Age  Ticket  \
# 20                               Fynney, Mr. Joseph J    male  35.0  239865
# 21                              Beesley, Mr. Lawrence    male  34.0  248698
# 22                        McGowan, Miss. Anna "Annie"  female  15.0  330923
# 23                       Sloper, Mr. William Thompson    male  28.0  113788
# 24                      Palsson, Miss. Torborg Danira  female   8.0  349909
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0  347077
# 27                     Fortune, Mr. Charles Alexander    male  19.0   19950
#
#         Fare
# 20   26.0000
# 21   13.0000
# 22    8.0292
# 23   35.5000
# 24   21.0750
# 25   31.3875
# 27  263.0000

# %% [markdown]
# <h2> c. DropNa </h2>

# %%
#this removes the entire row if any of row values is NaN
thirddf=df.dropna()
thirddf
# Out:
#                                                  Name     Sex   Age  Ticket  \
# 20                               Fynney, Mr. Joseph J    male  35.0  239865
# 21                              Beesley, Mr. Lawrence    male  34.0  248698
# 22                        McGowan, Miss. Anna "Annie"  female  15.0  330923
# 23                       Sloper, Mr. William Thompson    male  28.0  113788
# 24                      Palsson, Miss. Torborg Danira  female   8.0  349909
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0  347077
# 27                     Fortune, Mr. Charles Alexander    male  19.0   19950
#
#         Fare
# 20   26.0000
# 21   13.0000
# 22    8.0292
# 23   35.5000
# 24   21.0750
# 25   31.3875
# 27  263.0000

# %% [markdown]
# ### Alternative approaches

# %%
dict = {'First Score':[100, np.nan, np.nan, 95], 
        'Second Score': [30, np.nan, 45, 56], 
        'Third Score':[52, np.nan, 80, 98], 
        'Fourth Score':[60, 67, 68, 65]}
df1 = pd.DataFrame(dict) 
df1
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0         52.0            60
# 1          NaN           NaN          NaN            67
# 2          NaN          45.0         80.0            68
# 3         95.0          56.0         98.0            65

# %%
df1 = pd.DataFrame(dict)       
df1.dropna(axis = 1)#along the column
# Out:
#    Fourth Score
# 0            60
# 1            67
# 2            68
# 3            65

# %%
df1 = pd.DataFrame(dict)       
df1.dropna(axis = 0)#along the row
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0         52.0            60
# 3         95.0          56.0         98.0            65

# %%
print("\nDropping a row with a minimum 3 NaN value using 'thresh' parameter\n",'-'*68, sep='')
print(df1.dropna(axis=0, thresh=3))
# Out:
# Dropping a row with a minimum 3 NaN value using 'thresh' parameter
# --------------------------------------------------------------------
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0         52.0            60
# 2          NaN          45.0         80.0            68
# 3         95.0          56.0         98.0            65

# %% [markdown]
# <h2> d. Fillna </h2>

# %%
fourthdf=df.fillna('missing value ')
fourthdf
# Out:
#                                                  Name     Sex             Age  \
# 20                               Fynney, Mr. Joseph J    male              35
# 21                              Beesley, Mr. Lawrence    male              34
# 22                        McGowan, Miss. Anna "Annie"  female              15
# 23                       Sloper, Mr. William Thompson    male              28
# 24                      Palsson, Miss. Torborg Danira  female               8
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female              38
# 26                            Emir, Mr. Farred Chehab    male  missing value
# 27                     Fortune, Mr. Charles Alexander    male              19
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female  missing value
# 29                                Todoroff, Mr. Lalio    male  missing value
#
#     Ticket      Fare
# 20  239865   26.0000
# 21  248698   13.0000
# 22  330923    8.0292
# 23  113788   35.5000
# 24  349909   21.0750
# 25  347077   31.3875
# 26    2631    7.2250
# 27   19950  263.0000
# 28  330959    7.8792
# 29  349216    7.8958

# %%
dict = {'First Score':[ 'Mango', np.nan, np.nan, 'Apple'], 
        'Second Score': ['Tom', np.nan, 'Jerry', 'Noody'], 
        'Third Score':[52, np.nan, 80, 98], 
        'Fourth Score':[60, 67, 68, 65]}
df2 = pd.DataFrame(dict) 
df2
# Out:
#   First Score Second Score  Third Score  Fourth Score
# 0       Mango          Tom         52.0            60
# 1         NaN          NaN          NaN            67
# 2         NaN        Jerry         80.0            68
# 3       Apple        Noody         98.0            65

# %%
sixthdf=df2.fillna('')
sixthdf
# Out:
#   First Score Second Score Third Score  Fourth Score
# 0       Mango          Tom          52            60
# 1                                                 67
# 2                    Jerry          80            68
# 3       Apple        Noody          98            65

# %%
print(df2.fillna(value=df2['Fourth Score'].mean()))
# Out:
#   First Score Second Score  Third Score  Fourth Score
# 0       Mango          Tom         52.0            60
# 1          65           65         65.0            67
# 2          65        Jerry         80.0            68
# 3       Apple        Noody         98.0            65

# %% [markdown]
# <h2> e. Replace </h2>

# %%
# will replace  Nan value in dataframe with value -10   
fivedf=df.replace(to_replace = np.nan, value = -10)
fivedf
# Out:
#                                                  Name     Sex   Age  Ticket  \
# 20                               Fynney, Mr. Joseph J    male  35.0  239865
# 21                              Beesley, Mr. Lawrence    male  34.0  248698
# 22                        McGowan, Miss. Anna "Annie"  female  15.0  330923
# 23                       Sloper, Mr. William Thompson    male  28.0  113788
# 24                      Palsson, Miss. Torborg Danira  female   8.0  349909
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0  347077
# 26                            Emir, Mr. Farred Chehab    male -10.0    2631
# 27                     Fortune, Mr. Charles Alexander    male  19.0   19950
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female -10.0  330959
# 29                                Todoroff, Mr. Lalio    male -10.0  349216
#
#         Fare
# 20   26.0000
# 21   13.0000
# 22    8.0292
# 23   35.5000
# 24   21.0750
# 25   31.3875
# 26    7.2250
# 27  263.0000
# 28    7.8792
# 29    7.8958
